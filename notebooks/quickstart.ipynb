# %% [markdown]
# # Quickstart: Loading the Sample Portfolio
#
# This notebook shows the bare minimum to load the sample portfolio as a
# DataFrame. It stops here on purpose — building the tools, agents, and
# pipeline is your job.
#
# Make sure you've installed the requirements first:
# ```
# pip install -r ../requirements.txt
# ```

# %%
import pandas as pd

portfolio = pd.read_csv("../sample_data/sample_portfolio.csv")
portfolio

# %%
# Quick sanity checks you might find useful while building your tools
print("Sectors present:", portfolio["sector"].unique())
print("Number of holdings:", len(portfolio))

# %% [markdown]
# ## Next steps (up to you)
#
# - Implement `calculate_returns()` and `calculate_allocation()` in
#   `src/tools.py`.
# - Wire them into `analyst_agent()` in `src/agents.py`.
# - Implement `advisor_agent()` to turn findings into plain-English advice
#   using an LLM API call.
# - Run the full pipeline via `src/main.py`, or continue prototyping here
#   in the notebook — whichever is faster for your team.
#
# Good luck!
